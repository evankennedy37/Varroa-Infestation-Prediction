# %% [markdown]
# ## Varroa Infestation Prediction - Model Fitter

# %% [markdown]
# #### Authors: Evan Kennedy, Mit Ghandi, Anbuchelvan Kumaravel

# %% [markdown]
# **Library Imports**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import xgboost as xgb
from clearml import Task
import time
import json

# %% [markdown]
# **Reading In Parameters (Model Name)**

# %%
#Opening the JSON config file
with open("../configs/model_config.json", "r") as f:
    config = json.load(f)

#Grabbing Values
model_name = config["model_name"]

# %% [markdown]
# **Initializing a ClearML Task**

# %%
# Initialize the ClearML task
task = Task.init(
    project_name="Varroa Infestation Prediction",
    task_name="XGBoost Optuna HPO"
)
logger = task.get_logger()
# Out:
# ClearML Task: created new task id=4ace07075ee84aaa86ea01399e779a0d
# Could not fetch GPU stats: NVML Shared Library Not Found
# ClearML results page: https://app.clear.ml/projects/ec82bc7c7de54e1bbd3e93c1e3e68734/experiments/4ace07075ee84aaa86ea01399e779a0d/output/log

# %% [markdown]
# Importing Processed Data

# %%
#Grabbing dataframe from processing file
combined_binary = pd.read_csv('outputs/processed_varroa_data.csv')

# %% [markdown]
# **Modelling**

# %% [markdown]
# Train-Validation-Test Split (60%, 20%, 20%)

# %%
#Note: Stratifying these splits by month to ensure roughly even distribution of seasonsality

#X and Y split
y_bin = combined_binary['infested']
X_bin = combined_binary.drop(columns=['sampling_id', 'infested', 'yard_id', 'hive_id', 'station_id'])

#Train-Validation-Test Split
from sklearn.model_selection import train_test_split

#Splitting off Test Set (20%)
X_bin_temp, X_bin_test, y_bin_temp, y_bin_test = train_test_split(
    X_bin, y_bin, test_size=0.2, stratify=X_bin['obs_month'], random_state=37
)

#Splitting remaining into Train and Validation Sets (60% & 20%)
X_bin_train, X_bin_val, y_bin_train, y_bin_val = train_test_split(
    X_bin_temp, y_bin_temp, test_size=0.25, stratify=X_bin_temp['obs_month'], random_state=37
)

# %% [markdown]
# Ensemble Regression (ie. Gradient Boosting w/ many Regression Trees)

# %%
#Optimizing hyperparameters, focusing on maximizing ROC-AUC
import optuna
from sklearn.metrics import log_loss, roc_auc_score
from optuna.samplers import TPESampler

#Getting Start Time
start_time = time.time()

#Running optimization
def objective(trial):
    params = {
        "max_depth":        trial.suggest_int("max_depth", 3, 15),
        "learning_rate":    trial.suggest_float("learning_rate", 0.001, 0.3),
        "n_estimators":     trial.suggest_int("n_estimators", 100, 500),
        "subsample":        trial.suggest_float("subsample", 0.5, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.5, 1.0),
        "reg_alpha":        trial.suggest_float("reg_alpha", 0.0, 5.0),
        "reg_lambda":       trial.suggest_float("reg_lambda", 0.0, 5.0),
        "gamma":            trial.suggest_float("gamma", 0.0, 2.0),
    }

    model = xgb.XGBClassifier(
        objective="binary:logistic",
        eval_metric="auc",
        early_stopping_rounds=50,
        random_state=37,
        nthread=1,
        tree_method='exact',
        **params
    )
    model.fit(
        X_bin_train, y_bin_train,
        eval_set=[(X_bin_val, y_bin_val)],
        verbose=False
    )

    preds = model.predict_proba(X_bin_val)[:, 1]
    auc = roc_auc_score(y_bin_val, preds)
    logloss = log_loss(y_bin_val, preds)

    #Log per-trial metrics to ClearML
    logger.report_scalar("val_auc", "Training AUC-ROC", value=auc, iteration=trial.number)
    logger.report_scalar("val_logloss", "Training Logloss", value=logloss, iteration=trial.number)
    
    #Logging Training Time to ClearML
    training_time = time.time() - start_time
    logger.report_scalar(
        title="Performance",
        series="Training Time (s)",
        value=training_time,
        iteration=trial.number
    )
    
    return auc

study = optuna.create_study(direction="maximize", sampler=TPESampler(seed=37))
study.optimize(objective, n_trials=50)

# Best results
print("Best AUC-ROC:", study.best_value)
print("Best params:", study.best_params)
# Out:
# [I 2026-05-03 22:54:33,576] A new study created in memory with name: no-name-aca8ab10-02ee-431d-be81-931453a7f8c9
# [I 2026-05-03 22:54:35,030] Trial 0 finished with value: 0.9571338893372792 and parameters: {'max_depth': 15, 'learning_rate': 0.13976535411701788, 'n_estimators': 177, 'subsample': 0.7909474384399959, 'colsample_bytree': 0.8100421050868136, 'reg_alpha': 3.4211200873158703, 'reg_lambda': 0.5171877750999904, 'gamma': 1.490951532568867}. Best is trial 0 with value: 0.9571338893372792.
# ClearML Monitor: GPU monitoring failed getting GPU reading, switching off GPU monitoring
# [I 2026-05-03 22:54:37,234] Trial 1 finished with value: 0.9645099094251637 and parameters: {'max_depth': 6, 'learning_rate': 0.22627395155614066, 'n_estimators': 417, 'subsample': 0.8137002981396799, 'colsample_bytree': 0.7217444218892007, 'reg_alpha': 4.817326762037329, 'reg_lambda': 4.485332768597761, 'gamma': 0.39360857615704825}. Best is trial 1 with value: 0.9645099094251637.
# [I 2026-05-03 22:54:39,364] Trial 2 finished with value: 0.9724912563895615 and parameters: {'max_depth': 10, 'learning_rate': 0.17243970669882297, 'n_estimators': 382, 'subsample': 0.9646310092004129, 'colsample_bytree': 0.5256149144438098, 'reg_alpha': 0.6740599445713391, 'reg_lambda': 0.5851425305822705, 'gamma': 0.7294495214011822}. Best is trial 2 with value: 0.9724912563895615.
# [I 2026-05-03 22:54:41,180] Trial 3 finished with value: 0.9692404268675455 and parameters: {'max_depth': 13, 'learning_rate': 0.2911025735372444, 'n_estimators': 233, 'subsample': 0.7392099370802507, 'colsample_bytree': 0.589468723757938, 'reg_alpha': 4.512672441747777, 'reg_lambda': 3.8178784253419535, 'gamma': 0.3977210608348909}. Best is trial 2 with value: 0.9724912563895615.
# [I 2026-05-03 22:54:42,785] Trial 4 finished with value: 0.974464173616716 and parameters: {'max_depth': 7, 'learning_rate': 0.17907909928237667, 'n_estimators': 116, 'subsample': 0.9123139915826536, 'colsample_bytree': 0.8201356913711239, 'reg_alpha': 0.09568505381418346, 'reg_lambda': 4.030191858462334, 'gamma': 0.8097853039702576}. Best is trial 4 with value: 0.974464173616716.
# [I 2026-05-03 22:54:44,930] Trial 5 finished with value: 0.9537933817594835 and parameters: {'max_depth': 3, 'learning_rate': 0.14010479128722952, 'n_estimators': 235, 'subsample': 0.7676997064249822, 'colsample_bytree': 0.9683957988572056, 'reg_alpha': 4.3827732497077, 'reg_lambda': 3.7603718015438665, 'gamma': 0.9299923562340253}. Best is trial 4 with value: 0.974464173616716.
# [I 2026-05-03 22:54:46,341] Trial 6 finished with value: 0.9401398977670163 and parameters: {'max_depth': 12, 'learning_rate': 0.012577682683486167, 'n_estimators': 372, 'subsample': 0.7094898095392498, 'colsample_bytree': 0.9514292302907547, 'reg_alpha': 4.725808161673396, 'reg_lambda': 4.8852562032134745, 'gamma': 1.1613486745683403}. Best is trial 4 with value: 0.974464173616716.
# [I 2026-05-03 22:54:47,551] Trial 7 finished with value: 0.9504080351537978 and parameters: {'max_depth': 15, 'learning_rate': 0.17659818186039863, 'n_estimators': 232, 'subsample': 0.7376308953876871, 'colsample_bytree': 0.721586144026549, 'reg_alpha': 3.650236033890357, 'reg_lambda': 3.1481615898063713, 'gamma': 1.726122692546409}. Best is trial 4 with value: 0.974464173616716.
# [I 2026-05-03 22:54:49,007] Trial 8 finished with value: 0.9551833916240695 and parameters: {'max_depth': 7, 'learning_rate': 0.20753490278138972, 'n_estimators': 267, 'subsample': 0.6023312741255857, 'colsample_bytree': 0.5198171865369383, 'reg_alpha': 2.9876034204062654, 'reg_lambda': 4.699903481178007, 'gamma': 1.9310016806769619}. Best is trial 4 with value: 0.974464173616716.
# [I 2026-05-03 22:54:51,030] Trial 9 finished with value: 0.9706752757600215 and parameters: {'max_depth': 13, 'learning_rate': 0.2777375837807693, 'n_estimators': 334, 'subsample': 0.7041222581962928, 'colsample_bytree': 0.9849495968826928, 'reg_alpha': 0.35685112849777545, 'reg_lambda': 3.436695014850626, 'gamma': 0.9420049571535429}. Best is trial 4 with value: 0.974464173616716.
# [I 2026-05-03 22:54:51,864] Trial 10 finished with value: 0.9621334409470004 and parameters: {'max_depth': 3, 'learning_rate': 0.07167383987146157, 'n_estimators': 108, 'subsample': 0.9846678671436795, 'colsample_bytree': 0.8400338517144005, 'reg_alpha': 1.6897843306469924, 'reg_lambda': 2.1108703361425585, 'gamma': 0.0008425369031663799}. Best is trial 4 with value: 0.974464173616716.
# [I 2026-05-03 22:54:54,048] Trial 11 finished with value: 0.9752712761187338 and parameters: {'max_depth': 9, 'learning_rate': 0.09845849099675949, 'n_estimators': 498, 'subsample': 0.9787380910973031, 'colsample_bytree': 0.5956081736224601, 'reg_alpha': 0.13487451664316097, 'reg_lambda': 0.5243548047533652, 'gamma': 0.6033784353875338}. Best is trial 11 with value: 0.9752712761187338.
# [I 2026-05-03 22:54:56,739] Trial 12 finished with value: 0.9722670612501121 and parameters: {'max_depth': 8, 'learning_rate': 0.10234502274633782, 'n_estimators': 498, 'subsample': 0.9037778656769831, 'colsample_bytree': 0.6410989178411554, 'reg_alpha': 1.3758531629379904, 'reg_lambda': 1.747042247821005, 'gamma': 0.5068320469542278}. Best is trial 11 with value: 0.9752712761187338.
# [I 2026-05-03 22:54:59,282] Trial 13 finished with value: 0.971594475831764 and parameters: {'max_depth': 5, 'learning_rate': 0.07160999564511741, 'n_estimators': 497, 'subsample': 0.8876576107308755, 'colsample_bytree': 0.8683164582501606, 'reg_alpha': 0.20135123138646063, 'reg_lambda': 1.4215995491261815, 'gamma': 1.2548194879575862}. Best is trial 11 with value: 0.9752712761187338.
# [I 2026-05-03 22:55:00,141] Trial 14 finished with value: 0.9515290108510448 and parameters: {'max_depth': 10, 'learning_rate': 0.010188822264680042, 'n_estimators': 104, 'subsample': 0.8880573888560834, 'colsample_bytree': 0.6508111664541769, 'reg_alpha': 1.2548710983565667, 'reg_lambda': 2.8500118343652554, 'gamma': 0.6796640329798821}. Best is trial 11 with value: 0.9752712761187338.
# [I 2026-05-03 22:55:01,930] Trial 15 finished with value: 0.9652945924132366 and parameters: {'max_depth': 9, 'learning_rate': 0.08803102565516227, 'n_estimators': 164, 'subsample': 0.999745590594573, 'colsample_bytree': 0.7831825268806323, 'reg_alpha': 1.9925803473266743, 'reg_lambda': 1.1214818661122816, 'gamma': 0.1366478095748827}. Best is trial 11 with value: 0.9752712761187338.
# [I 2026-05-03 22:55:05,989] Trial 16 finished with value: 0.9754506322302933 and parameters: {'max_depth': 5, 'learning_rate': 0.23066632210363774, 'n_estimators': 447, 'subsample': 0.9286306990888937, 'colsample_bytree': 0.9046400632533614, 'reg_alpha': 0.7851011040070438, 'reg_lambda': 2.456801004482399, 'gamma': 0.7255372274644444}. Best is trial 16 with value: 0.9754506322302933.
# [I 2026-05-03 22:55:08,814] Trial 17 finished with value: 0.9718410904851582 and parameters: {'max_depth': 5, 'learning_rate': 0.252143448766008, 'n_estimators': 453, 'subsample': 0.5337400396230869, 'colsample_bytree': 0.9013834490794436, 'reg_alpha': 1.0012162597282157, 'reg_lambda': 0.004378042012423977, 'gamma': 1.1789514833541666}. Best is trial 16 with value: 0.9754506322302933.
# [I 2026-05-03 22:55:11,240] Trial 18 finished with value: 0.9679400950587391 and parameters: {'max_depth': 11, 'learning_rate': 0.11607422434639027, 'n_estimators': 444, 'subsample': 0.8412975630323953, 'colsample_bytree': 0.6631029169877873, 'reg_alpha': 2.264079827275133, 'reg_lambda': 2.3613421103167513, 'gamma': 0.6185776079647133}. Best is trial 16 with value: 0.9754506322302933.
# [I 2026-05-03 22:55:14,866] Trial 19 finished with value: 0.975876602995247 and parameters: {'max_depth': 4, 'learning_rate': 0.049019592932491446, 'n_estimators': 454, 'subsample': 0.9435329707340299, 'colsample_bytree': 0.5827837604991117, 'reg_alpha': 0.7980536865662501, 'reg_lambda': 0.9262432628171218, 'gamma': 0.2164375068646741}. Best is trial 19 with value: 0.975876602995247.
# [I 2026-05-03 22:55:20,834] Trial 20 finished with value: 0.9677158999192897 and parameters: {'max_depth': 4, 'learning_rate': 0.04086917240443996, 'n_estimators': 333, 'subsample': 0.8530132546225174, 'colsample_bytree': 0.9224843190649515, 'reg_alpha': 2.597283321481206, 'reg_lambda': 2.6388822787207062, 'gamma': 0.25658929384466067}. Best is trial 19 with value: 0.975876602995247.
# [I 2026-05-03 22:55:24,332] Trial 21 finished with value: 0.976257734732311 and parameters: {'max_depth': 5, 'learning_rate': 0.04736254577271559, 'n_estimators': 463, 'subsample': 0.9357618174633551, 'colsample_bytree': 0.5827113126028148, 'reg_alpha': 0.7282697363078281, 'reg_lambda': 0.9114962550536465, 'gamma': 0.27291384991270135}. Best is trial 21 with value: 0.976257734732311.
# [I 2026-05-03 22:55:26,879] Trial 22 finished with value: 0.9742399784772666 and parameters: {'max_depth': 5, 'learning_rate': 0.05099502664470329, 'n_estimators': 443, 'subsample': 0.9399847489475687, 'colsample_bytree': 0.5711848506289053, 'reg_alpha': 0.8126288115168618, 'reg_lambda': 0.9939968464608767, 'gamma': 0.2115256921634836}. Best is trial 21 with value: 0.976257734732311.
# [I 2026-05-03 22:55:30,746] Trial 23 finished with value: 0.9724464173616716 and parameters: {'max_depth': 4, 'learning_rate': 0.03453170407183601, 'n_estimators': 401, 'subsample': 0.9271571283177387, 'colsample_bytree': 0.7149990123279275, 'reg_alpha': 1.6877283620902601, 'reg_lambda': 1.5431922570354852, 'gamma': 0.0627123231792335}. Best is trial 21 with value: 0.976257734732311.
# [I 2026-05-03 22:55:32,146] Trial 24 finished with value: 0.9773338714016679 and parameters: {'max_depth': 6, 'learning_rate': 0.2234441753946071, 'n_estimators': 460, 'subsample': 0.8427914506404369, 'colsample_bytree': 0.5580665090563492, 'reg_alpha': 0.6678890151796596, 'reg_lambda': 1.9676428689675345, 'gamma': 0.329209903190261}. Best is trial 24 with value: 0.9773338714016679.
# [I 2026-05-03 22:55:34,103] Trial 25 finished with value: 0.9737691686844229 and parameters: {'max_depth': 7, 'learning_rate': 0.12144866327595143, 'n_estimators': 470, 'subsample': 0.8578835574501164, 'colsample_bytree': 0.5044242373950387, 'reg_alpha': 1.4284158703829801, 'reg_lambda': 1.786774599855208, 'gamma': 0.3302325887807439}. Best is trial 24 with value: 0.9773338714016679.
# [I 2026-05-03 22:55:36,267] Trial 26 finished with value: 0.9782754909873553 and parameters: {'max_depth': 4, 'learning_rate': 0.06395162806316408, 'n_estimators': 346, 'subsample': 0.6498523476737105, 'colsample_bytree': 0.5584962925008867, 'reg_alpha': 0.6287637960269776, 'reg_lambda': 0.03029034545323972, 'gamma': 0.4825670141779307}. Best is trial 26 with value: 0.9782754909873553.
# [I 2026-05-03 22:55:37,363] Trial 27 finished with value: 0.9772666128598332 and parameters: {'max_depth': 6, 'learning_rate': 0.0696246705791163, 'n_estimators': 330, 'subsample': 0.6387947528432544, 'colsample_bytree': 0.540476338897547, 'reg_alpha': 0.52616557686133, 'reg_lambda': 0.01534618333518148, 'gamma': 0.473495886371526}. Best is trial 26 with value: 0.9782754909873553.
# [I 2026-05-03 22:55:38,883] Trial 28 finished with value: 0.9786117836965295 and parameters: {'max_depth': 6, 'learning_rate': 0.20095362060401456, 'n_estimators': 333, 'subsample': 0.6412978750911235, 'colsample_bytree': 0.5474250800666617, 'reg_alpha': 0.4639361642318713, 'reg_lambda': 0.13399310747674265, 'gamma': 0.4603674287288465}. Best is trial 28 with value: 0.9786117836965295.
# [I 2026-05-03 22:55:42,162] Trial 29 finished with value: 0.9750022419513945 and parameters: {'max_depth': 6, 'learning_rate': 0.20067578729109437, 'n_estimators': 294, 'subsample': 0.6320636508834826, 'colsample_bytree': 0.6287419588277403, 'reg_alpha': 0.0063409194190361395, 'reg_lambda': 0.2716925084909336, 'gamma': 1.3722875545893984}. Best is trial 28 with value: 0.9786117836965295.
# [I 2026-05-03 22:55:43,915] Trial 30 finished with value: 0.9781633934176308 and parameters: {'max_depth': 8, 'learning_rate': 0.15269528181126002, 'n_estimators': 374, 'subsample': 0.5628253537646032, 'colsample_bytree': 0.6799642395838877, 'reg_alpha': 1.026010690576939, 'reg_lambda': 0.3828828323181397, 'gamma': 0.5214416288455728}. Best is trial 28 with value: 0.9786117836965295.
# [I 2026-05-03 22:55:46,798] Trial 31 finished with value: 0.9761456371625863 and parameters: {'max_depth': 8, 'learning_rate': 0.15189059599053825, 'n_estimators': 368, 'subsample': 0.5007958009196956, 'colsample_bytree': 0.6829050539099683, 'reg_alpha': 1.0910179172602736, 'reg_lambda': 0.35820866772629356, 'gamma': 0.5731852785244647}. Best is trial 28 with value: 0.9786117836965295.
# [I 2026-05-03 22:55:47,978] Trial 32 finished with value: 0.9784100080710251 and parameters: {'max_depth': 8, 'learning_rate': 0.2386293744110889, 'n_estimators': 303, 'subsample': 0.5707049178722804, 'colsample_bytree': 0.5433196748075287, 'reg_alpha': 0.5216443376867538, 'reg_lambda': 0.7049281358497606, 'gamma': 0.43883720060520026}. Best is trial 28 with value: 0.9786117836965295.
# [I 2026-05-03 22:55:49,245] Trial 33 finished with value: 0.9743969150748812 and parameters: {'max_depth': 8, 'learning_rate': 0.24547485424470608, 'n_estimators': 294, 'subsample': 0.576413267548157, 'colsample_bytree': 0.6171258283729087, 'reg_alpha': 0.48183683102964836, 'reg_lambda': 0.724474342947164, 'gamma': 0.45647618215167557}. Best is trial 28 with value: 0.9786117836965295.
# [I 2026-05-03 22:55:52,523] Trial 34 finished with value: 0.9734328759752489 and parameters: {'max_depth': 9, 'learning_rate': 0.15393106466667844, 'n_estimators': 351, 'subsample': 0.6706363449863155, 'colsample_bytree': 0.5510885158382255, 'reg_alpha': 1.594561133823488, 'reg_lambda': 0.19912015606479702, 'gamma': 0.8798147011834666}. Best is trial 28 with value: 0.9786117836965295.
# [I 2026-05-03 22:55:58,198] Trial 35 finished with value: 0.9751815980629541 and parameters: {'max_depth': 7, 'learning_rate': 0.1975122656840485, 'n_estimators': 408, 'subsample': 0.5522237037640496, 'colsample_bytree': 0.7690346032121531, 'reg_alpha': 1.0815067411292842, 'reg_lambda': 1.2708061162834041, 'gamma': 0.7843454581521221}. Best is trial 28 with value: 0.9786117836965295.
# [I 2026-05-03 22:56:01,239] Trial 36 finished with value: 0.9744865931306609 and parameters: {'max_depth': 10, 'learning_rate': 0.2740494958057824, 'n_estimators': 267, 'subsample': 0.6089601280218911, 'colsample_bytree': 0.6832621175750182, 'reg_alpha': 0.3170400355590166, 'reg_lambda': 0.6273811744832338, 'gamma': 1.0430473088981096}. Best is trial 28 with value: 0.9786117836965295.
# [I 2026-05-03 22:56:05,054] Trial 37 finished with value: 0.975562729800018 and parameters: {'max_depth': 8, 'learning_rate': 0.1635087838948028, 'n_estimators': 312, 'subsample': 0.6796875665291815, 'colsample_bytree': 0.5018785539188424, 'reg_alpha': 3.716968876062622, 'reg_lambda': 0.42138560510402145, 'gamma': 0.40716258524679394}. Best is trial 28 with value: 0.9786117836965295.
# [I 2026-05-03 22:56:07,357] Trial 38 finished with value: 0.9752040175768988 and parameters: {'max_depth': 3, 'learning_rate': 0.1276733789340634, 'n_estimators': 384, 'subsample': 0.5422677856839602, 'colsample_bytree': 0.6108013407813855, 'reg_alpha': 1.9899946829389052, 'reg_lambda': 0.7426412372047455, 'gamma': 0.5831108513150411}. Best is trial 28 with value: 0.9786117836965295.
# [I 2026-05-03 22:56:09,369] Trial 39 finished with value: 0.9777598421666218 and parameters: {'max_depth': 7, 'learning_rate': 0.187468400670614, 'n_estimators': 277, 'subsample': 0.5727732792118816, 'colsample_bytree': 0.5373726900293364, 'reg_alpha': 1.028448826015949, 'reg_lambda': 0.21184983059206303, 'gamma': 0.13152937455033642}. Best is trial 28 with value: 0.9786117836965295.
# [I 2026-05-03 22:56:12,015] Trial 40 finished with value: 0.9780064568200162 and parameters: {'max_depth': 11, 'learning_rate': 0.2179051407138306, 'n_estimators': 209, 'subsample': 0.6501202398996572, 'colsample_bytree': 0.6020129871472992, 'reg_alpha': 0.47686226660903086, 'reg_lambda': 0.050528411257391076, 'gamma': 0.8604947245181919}. Best is trial 28 with value: 0.9786117836965295.
# [I 2026-05-03 22:56:14,342] Trial 41 finished with value: 0.9754954712581831 and parameters: {'max_depth': 11, 'learning_rate': 0.215268553053933, 'n_estimators': 180, 'subsample': 0.6453004851006118, 'colsample_bytree': 0.598561702226918, 'reg_alpha': 0.4609029207289461, 'reg_lambda': 0.5053293046832061, 'gamma': 0.825200499779451}. Best is trial 28 with value: 0.9786117836965295.
# [I 2026-05-03 22:56:15,939] Trial 42 finished with value: 0.9769975786924938 and parameters: {'max_depth': 13, 'learning_rate': 0.23912304186033895, 'n_estimators': 207, 'subsample': 0.5953510048320649, 'colsample_bytree': 0.5274016873962635, 'reg_alpha': 0.277555777054996, 'reg_lambda': 0.02691106008669426, 'gamma': 0.7183757267045333}. Best is trial 28 with value: 0.9786117836965295.
# [I 2026-05-03 22:56:19,450] Trial 43 finished with value: 0.968724778046812 and parameters: {'max_depth': 14, 'learning_rate': 0.25910225927564795, 'n_estimators': 362, 'subsample': 0.7811826351206027, 'colsample_bytree': 0.5664430686565645, 'reg_alpha': 0.5221530715413847, 'reg_lambda': 0.7082506016527549, 'gamma': 1.038180828448323}. Best is trial 28 with value: 0.9786117836965295.
# [I 2026-05-03 22:56:22,371] Trial 44 finished with value: 0.9761680566765313 and parameters: {'max_depth': 11, 'learning_rate': 0.18721486070788035, 'n_estimators': 318, 'subsample': 0.6711521185400607, 'colsample_bytree': 0.6982985387811258, 'reg_alpha': 0.042354866791393775, 'reg_lambda': 0.2217834412901744, 'gamma': 0.37814273258276415}. Best is trial 28 with value: 0.9786117836965295.
# [I 2026-05-03 22:56:28,349] Trial 45 finished with value: 0.9743296565330464 and parameters: {'max_depth': 12, 'learning_rate': 0.1670814737691237, 'n_estimators': 246, 'subsample': 0.7179450010525332, 'colsample_bytree': 0.7411298249857536, 'reg_alpha': 0.8981337830670215, 'reg_lambda': 4.357177989388948, 'gamma': 0.48152210292042874}. Best is trial 28 with value: 0.9786117836965295.
# [I 2026-05-03 22:56:30,759] Trial 46 finished with value: 0.9749798224374496 and parameters: {'max_depth': 10, 'learning_rate': 0.2152139828720948, 'n_estimators': 342, 'subsample': 0.5071382620218381, 'colsample_bytree': 0.6258377609253101, 'reg_alpha': 1.222398834191067, 'reg_lambda': 0.41759765634920687, 'gamma': 0.6595691799133325}. Best is trial 28 with value: 0.9786117836965295.
# [I 2026-05-03 22:56:34,083] Trial 47 finished with value: 0.975562729800018 and parameters: {'max_depth': 8, 'learning_rate': 0.13459823350689565, 'n_estimators': 383, 'subsample': 0.6183940883416118, 'colsample_bytree': 0.5187249717940764, 'reg_alpha': 0.6257003803329477, 'reg_lambda': 1.2307533068390697, 'gamma': 1.6127409720062618}. Best is trial 28 with value: 0.9786117836965295.
# [I 2026-05-03 22:56:37,348] Trial 48 finished with value: 0.9767061250112098 and parameters: {'max_depth': 9, 'learning_rate': 0.2886229616471642, 'n_estimators': 145, 'subsample': 0.5842822633965469, 'colsample_bytree': 0.6543728606138911, 'reg_alpha': 3.027124843518733, 'reg_lambda': 0.8021411393818594, 'gamma': 0.5440133246029257}. Best is trial 28 with value: 0.9786117836965295.
# [I 2026-05-03 22:56:39,561] Trial 49 finished with value: 0.9768630616088243 and parameters: {'max_depth': 6, 'learning_rate': 0.23068844263831473, 'n_estimators': 425, 'subsample': 0.7546432848125063, 'colsample_bytree': 0.5548594592928893, 'reg_alpha': 0.288467889498339, 'reg_lambda': 0.14760560331871003, 'gamma': 0.9389308532715638}. Best is trial 28 with value: 0.9786117836965295.
# Best AUC-ROC: 0.9786117836965295
# Best params: {'max_depth': 6, 'learning_rate': 0.20095362060401456, 'n_estimators': 333, 'subsample': 0.6412978750911235, 'colsample_bytree': 0.5474250800666617, 'reg_alpha': 0.4639361642318713, 'reg_lambda': 0.13399310747674265, 'gamma': 0.4603674287288465}

# %%
#Using optimized hyperparameters
best_model = xgb.XGBClassifier(
    objective="binary:logistic",
    eval_metric="auc",
    early_stopping_rounds=50,
    random_state=37,
    **study.best_params
)
best_model.fit(
    X_bin_train, y_bin_train,
    eval_set=[(X_bin_val, y_bin_val)],
    verbose=False
)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.5474250800666617, device=None,
#               early_stopping_rounds=50, enable_categorical=False,
#               eval_metric='auc', feature_types=None, feature_weights=None,
#               gamma=0.4603674287288465, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.20095362060401456,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=333, n_jobs=None,
#               num_parallel_tree=None, ...)

# %% [markdown]
# Classification Performance

# %%
from sklearn.metrics import accuracy_score, log_loss

#Predicted class labels
y_bin_test_pred = best_model.predict(X_bin_test)

#Predicted probabilities
y_bin_test_prob = best_model.predict_proba(X_bin_test)

#Accuracy
accuracy = accuracy_score(y_bin_test, y_bin_test_pred)

#Log loss (binary or multiclass-safe)
loss = log_loss(y_bin_test, y_bin_test_prob)

print("Accuracy:", accuracy)
print("Log Loss:", loss)
# Out:
# Accuracy: 0.9564459930313589
# Log Loss: 0.14462220777504714

# %%
from sklearn.metrics import roc_curve, roc_auc_score

#ROC-AUC Score
y_bin_test_probs = best_model.predict_proba(X_bin_test)[:, 1]
auc = roc_auc_score(y_bin_test, y_bin_test_probs)
print(f"ROC-AUC Score: {auc:.4f}")

#ROC Curve
fpr, tpr, thresholds = roc_curve(y_bin_test, y_bin_test_probs)
plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {auc:.2f})')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()

#Random guessing diagonal for visual comparison
plt.plot([0, 1], [0, 1], 'k--')
plt.show()
# Out:
# ROC-AUC Score: 0.9183

# %% [markdown]
# Logging to ClearML

# %%
# Log best hyperparameters
task.connect(study.best_params)

# Log final test metrics
logger = task.get_logger()
logger.report_scalar("test_accuracy", "final_test_accuracy", value=accuracy, iteration=0)
logger.report_scalar("test_log_loss", "final_test_log_loss", value=loss, iteration=0)
logger.report_scalar("test_auc", "final_test_auc", value=auc, iteration=0)

# Log the ROC curve plot
logger.report_matplotlib_figure(
    title="ROC Curve",
    series="test",
    figure=plt.gcf(),   # call this right after plt.show()
    iteration=0
)

# Upload the saved model as an artifact
task.upload_artifact("varroa_predictor", artifact_object="varroa_predictor.json")

# Mark task complete
task.close()

# %% [markdown]
# Exporting Model

# %%
#Saving model
best_model.save_model('outputs/' + model_name)
